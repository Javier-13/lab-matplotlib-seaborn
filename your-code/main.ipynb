# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import math
import pandas as pd
import seaborn as sns
sns.set(style="white")

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x, y, label='linear')
plt.plot(x, z, label='quadratic')

plt.xlabel('x')
plt.ylabel('y')

plt.title("Linear vs Non Linear Plots")
plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
fig, [ax1, ax2] = plt.subplots(1,2)
ax1.plot(x,y)
ax1.set_title('LINEAR PLOT')   
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')   

ax2.plot(x,z)
ax2.set_title('COSINE PLOT')
ax2.set_xlabel('x label')
ax2.set_ylabel('y label')
# Out:
# Text(0, 0.5, 'y label')

# %%
# Method 2
fig, [ax1, ax2] = plt.subplots(1,2)
ax1.plot(x, y)
ax1.set_title('LINEAR PLOT')   
ax1.set_xlabel('x')     
ax1.set_ylabel('y')   

ax2.plot(x, z)
ax2.set_title('COSINE PLOT')
ax2.set_xlabel('x')
ax2.set_ylabel('y')

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, [ax1, ax2] = plt.subplots(1,2, figsize=(15,5))
ax1.plot(x, y)
ax1.set_title('LINEAR PLOT')   
ax1.set_xlabel('x')     
ax1.set_ylabel('y')   

ax2.plot(x, z)
ax2.set_title('COSINE PLOT')
ax2.set_xlabel('x')
ax2.set_ylabel('y')

plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
plt.yscale('log')
plt.xscale('log')

i = np.arange(0,100)
j = i**2
k = math.e ** i
plt.plot(i, j, label='cuadratic')
plt.plot(i, k, label='e')

plt.xlabel('x')
plt.ylabel('y')

plt.title("Linear vs Non Linear Plots")
plt.legend()
plt.show()

# %%
i = np.arange(0,100)
j = i**2
k = math.e ** i
plt.plot(i, j, label='cuadratic')
plt.plot(i, k, label='e')

plt.xlabel('x')
plt.ylabel('y')

plt.title("Linear vs Non Linear Plots")
plt.legend()
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
sns.set(style="white")
fit2 = pd.read_csv('Fitbit2.csv')
fit2.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
fig, [ax1, ax2] = plt.subplots(1,2)
ax1.bar(by1['Months_encoded'].index,by1['Steps'])
ax1.set_title('By Month')   
ax1.set_xlabel('Month')     
ax1.set_ylabel('Steps')   

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
ax2.bar(by2['Work_or_Weekend'].index,by2['Steps'])
ax2.set_title('Steps / Work')
ax2.set_xlabel('Work / weekend')
ax2.set_ylabel('Steps')
# Out:
# Text(0, 0.5, 'Steps')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
c_names = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

for i in c_names: 
    plt.scatter(fit2['Steps'], fit2[i])
    plt.title(f"Steps / {i}")
    plt.xlabel('Steps')
    plt.ylabel(f"{i}")
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titan = pd.read_csv('titanic.csv')
titan.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1       0.0       3
# 1           1            2       1.0       1
# 2           2            3       1.0       3
# 3           3            4       1.0       1
# 4           4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titan.dtypes
# Out:
# Unnamed: 0       int64
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titan.select_dtypes(include=['float64', 'int64']).columns
# Out:
# Index(['Unnamed: 0', 'PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp',
#        'Parch', 'Fare'],
#       dtype='object')

# %%
# CATEGORICAL VARIABLES
# your code here
titan.select_dtypes(include=['object']).columns
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
mpl.style.use('classic')
mpl.figure.Figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
bins = [i for i in range(0, 91, 1)]
plt.hist(titan['Age'], bins)
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
bins1 = [10, 20, 50]

for i in range(3):
    plt.hist(titan['Age'], bins1[i])
    plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
It affects the precision of the visualization, 
the more bins the more precision we have
"""
# Out:
# '\nIt affects the precision of the visualization, \nthe more bins the more precision we have\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.distplot(titan['Age'])

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
gender = titan.groupby('Gender').count().reset_index()
plt.bar(gender['Gender'],gender['Name'])
# Out:
# <BarContainer object of 2 artists>

# %%
# Method 2 - seaborn
# your code here
sns.catplot(x="Gender", kind="count", data=titan);

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.catplot(x="Pclass", kind="count", data=titan);

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
plt.boxplot(titan['Age'])
plt.ylim(0,85)
# Out:
# (0, 85)

# %%
"""
I've used boxplot as it is giving us all the 'centils' we might need
"""
# Out:
# "\nI've used boxplot as it is giving us all the 'centils' we might need\n"

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
75% of people are less than 38 years old,
25% of people are more than 22 yo, 
being28 the median value. Also we have some outsiders 
"""
# Out:
# '\n75% of people are less than 38 years old,\n25% of people are more than 22 yo, \nbeing28 the median value. Also we have some outsiders \n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.violinplot(titan['Age'])

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
As long as it was asked, it plots the distribution of the values
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib<
# your code here
plt.scatter(titan['Age'], titan['Fare'])

# %%
# Method 2 - seaborn
# your code here
sns.scatterplot(titan['Age'], titan['Fare'])

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
corr = titan.corr()
sns.heatmap(corr, annot=True)

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Fare- Pclass
Age - Pclass
Survived -Pclass
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.boxplot(x='Pclass', y='Age', data=titan)

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
g_distrib = sns.FacetGrid(data=titan, col="Gender")
g_distrib.map(plt.hist, "Age")
